# %%
import pandas as pd
import numpy as np
import math

# %%
def ent(column):
    column = list(column)
    entropy = 0
    total = len(column)
    elements, counts = np.unique(column, return_counts=True)
    numElems = len(elements)
            
    for elem in range(len(counts)):
        pi = counts[elem]/total
        if(numElems < 2):
            entropy = entropy - pi*(math.log(pi,2))
        else:
            entropy = entropy - pi*(math.log(pi, numElems))

    return entropy

# %%
#("String", dataframe with last column being the output column, int)
def infoGain(colName, data, splitOn):
    marker = 0
    baseEntropy = ent(data[colName])
    
    elements, counts = np.unique(data[colName], return_counts=True)
    lowCount = 0
    highCount = 0
    
    for i in range(len(elements)):
        if(elements[i] < splitOn):
            lowCount = lowCount + counts[i]
        else:
            highCount = highCount + counts[i]
    
    df1, df2 = [x for _, x in data.groupby(data[colName] < splitOn)]
    print("Left Return:\n", df1)
    print("Right Return:\n", df2)
    print("")
    #Returns Entropy of data - Scaled Entropy of #<splitOn - Scaled Entropy #>=splitOn  
    return (baseEntropy - ((lowCount/(highCount+lowCount))*(ent(df1.iloc[ :, -1:]))) - ((highCount/(highCount+lowCount))*(ent(df2.iloc[ :, -1:])))), df1, df2

# %%
def BestSplitOriginal(data):
    mostInfoGain = 0
    labels = list(data.columns.values)
    for i in range(data.shape[1]-1):
        elements, counts = np.unique(data[labels[i]], return_counts=True)
        print("Label:", labels[i])
        for j in range(1, len(elements)):
            gain, leftPart, rightPart = infoGain(labels[i], data, elements[j])
            if(gain > mostInfoGain):
                mostInfoGain = gain
                colToSplitOn = labels[i]
                digitToSplitOn = elements[j]
                leftPartition = leftPart
                rightPartition = rightPart
    print("\n\n\nOUTPUT:\nThe column {} has {} information gain if split on {}.".format(colToSplitOn, mostInfoGain, digitToSplitOn))
    print(leftPartition)
    print(rightPartition)

# %%
D = {"A":[11,10,9,19,7,4,6,5,12,2,0],
    "Y":[1,0,0,0,0,0,0,0,2,2,2]}
D = pd.DataFrame(D)
BestSplitOriginal(D)
# Out:
# Label: A
# Left Return:
#      A  Y
# 0  11  1
# 1  10  0
# 2   9  0
# 3  19  0
# 4   7  0
# 5   4  0
# 6   6  0
# 7   5  0
# 8  12  2
# 9   2  2
# Right Return:
#      A  Y
# 10  0  2
#
# Left Return:
#      A  Y
# 0  11  1
# 1  10  0
# 2   9  0
# 3  19  0
# 4   7  0
# 5   4  0
# 6   6  0
# 7   5  0
# 8  12  2
# Right Return:
#      A  Y
# 9   2  2
# 10  0  2
#
# Left Return:
#      A  Y
# 0  11  1
# 1  10  0
# 2   9  0
# 3  19  0
# 4   7  0
# 6   6  0
# 7   5  0
# 8  12  2
# Right Return:
#      A  Y
# 5   4  0
# 9   2  2
# 10  0  2
#
# Left Return:
#      A  Y
# 0  11  1
# 1  10  0
# 2   9  0
# 3  19  0
# 4   7  0
# 6   6  0
# 8  12  2
# Right Return:
#      A  Y
# 5   4  0
# 7   5  0
# 9   2  2
# 10  0  2
#
# Left Return:
#      A  Y
# 0  11  1
# 1  10  0
# 2   9  0
# 3  19  0
# 4   7  0
# 8  12  2
# Right Return:
#      A  Y
# 5   4  0
# 6   6  0
# 7   5  0
# 9   2  2
# 10  0  2
#
# Left Return:
#      A  Y
# 0  11  1
# 1  10  0
# 2   9  0
# 3  19  0
# 8  12  2
# Right Return:
#      A  Y
# 4   7  0
# 5   4  0
# 6   6  0
# 7   5  0
# 9   2  2
# 10  0  2
#
# Left Return:
#      A  Y
# 0  11  1
# 1  10  0
# 3  19  0
# 8  12  2
# Right Return:
#      A  Y
# 2   9  0
# 4   7  0
# 5   4  0
# 6   6  0
# 7   5  0
# 9   2  2
# 10  0  2
#
# Left Return:
#      A  Y
# 0  11  1
# 3  19  0
# 8  12  2
# Right Return:
#       A  Y
# 1   10  0
# 2    9  0
# 4    7  0
# 5    4  0
# 6    6  0
# 7    5  0
# 9    2  2
# 10   0  2
#
# Left Return:
#      A  Y
# 3  19  0
# 8  12  2
# Right Return:
#       A  Y
# 0   11  1
# 1   10  0
# 2    9  0
# 4    7  0
# 5    4  0
# 6    6  0
# 7    5  0
# 9    2  2
# 10   0  2
#
# Left Return:
#      A  Y
# 3  19  0
# Right Return:
#       A  Y
# 0   11  1
# 1   10  0
# 2    9  0
# 4    7  0
# 5    4  0
# 6    6  0
# 7    5  0
# 8   12  2
# 9    2  2
# 10   0  2
#
#
#
#
# OUTPUT:
# The column A has 1.0000000000000002 information gain if split on 2.
#     A  Y
# 0  11  1
# 1  10  0
# 2   9  0
# 3  19  0
# 4   7  0
# 5   4  0
# 6   6  0
# 7   5  0
# 8  12  2
# 9   2  2
#     A  Y
# 10  0  2

# %%
#NetworkX library visualize decision tree
#Shuffle data and then fold

def main():
    data = {'Outlook' :    [0,2,2],
            'Temperature': [0,0,0],
            'Wind' :       [1,2,1],
            'Humidity':    [1,1,1]}
    output = {'PlayTennis':[0,0,1]}
            
    data = pd.DataFrame(data)
    output = pd.DataFrame(output)
    
    labels = list(data.columns.values)
    
    arr = [1,1,2,2,4,5,6,7,8,100]
    print("Q2 quantile of arr : ", np.quantile(arr, .50))
